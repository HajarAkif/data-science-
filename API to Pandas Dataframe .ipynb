# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import json

# %%
titre_du_film=input('Entrez le nom du film :')
api_url = "http://www.omdbapi.com/?t="+str(titre_du_film)+"&apikey=d21cabe0"
response = requests.get(api_url)
response.json()
# Out:
# Entrez le nom du film :Silent Hill
# {'Title': 'Silent Hill',
#  'Year': '2006',
#  'Rated': 'R',
#  'Released': '21 Apr 2006',
#  'Runtime': '125 min',
#  'Genre': 'Horror, Mystery',
#  'Director': 'Christophe Gans',
#  'Writer': 'Roger Avary',
#  'Actors': 'Radha Mitchell, Laurie Holden, Sean Bean',
#  'Plot': 'A woman, Rose, goes in search for her adopted daughter within the confines of a strange, desolate town called Silent Hill.',
#  'Language': 'English',
#  'Country': 'Canada, France',
#  'Awards': '8 nominations',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BOWQzNTU3NGUtNDAxMi00ZjFjLTkyYWUtYjgwZDJiMDljZWY4XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '32%'},
#   {'Source': 'Metacritic', 'Value': '31/100'}],
#  'Metascore': '31',
#  'imdbRating': '6.5',
#  'imdbVotes': '237,221',
#  'imdbID': 'tt0384537',
#  'Type': 'movie',
#  'DVD': '22 Aug 2006',
# ...

# %%
import pandas as pd
df = pd.DataFrame(dict(response.json()))
df.head()
# Out:
#          Title  Year Rated     Released  Runtime            Genre  \
# 0  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
# 1  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
# 2  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
#
#           Director       Writer                                    Actors  \
# 0  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
# 1  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
# 2  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
#
#                                                 Plot  ... Metascore  \
# 0  A woman, Rose, goes in search for her adopted ...  ...        31
# 1  A woman, Rose, goes in search for her adopted ...  ...        31
# 2  A woman, Rose, goes in search for her adopted ...  ...        31
#
#   imdbRating imdbVotes     imdbID   Type          DVD    BoxOffice Production  \
# ...

# %%
import pandas as pd
df = pd.DataFrame.from_dict(response.json())
df.head()
# Out:
#          Title  Year Rated     Released  Runtime            Genre  \
# 0  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
# 1  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
# 2  Silent Hill  2006     R  21 Apr 2006  125 min  Horror, Mystery
#
#           Director       Writer                                    Actors  \
# 0  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
# 1  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
# 2  Christophe Gans  Roger Avary  Radha Mitchell, Laurie Holden, Sean Bean
#
#                                                 Plot  ... Metascore  \
# 0  A woman, Rose, goes in search for her adopted ...  ...        31
# 1  A woman, Rose, goes in search for her adopted ...  ...        31
# 2  A woman, Rose, goes in search for her adopted ...  ...        31
#
#   imdbRating imdbVotes     imdbID   Type          DVD    BoxOffice Production  \
# ...
